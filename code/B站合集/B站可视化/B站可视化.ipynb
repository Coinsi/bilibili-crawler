# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv')
df.head()
# Out:
#                                                   标题  \
# 0                               【罗翔】张三打牌只算娱乐？怎样判定赌博？
# 1                        【罗翔】村民修桥收费被判处寻衅滋事，这件事应该如何看？
# 2  【罗翔】张三莫名坐牢，有了犯罪记录该怎么办？附《流程图》、《出具无犯罪记录证明的申请》与《行...
# 3                       【罗翔】欠款？上门击毙！我是孙中山，打钱！骗子这么傻么？
# 4           【罗翔】“铁马冰河”买药治疗癫痫女儿，以治病为名购买麻醉药品构成什么走私毒品罪吗
#
#                                                   描述           Bv号      播放量  \
# 0  对于赌博，有行政处罚和刑事惩罚两种。面对诱惑，我们只能选择远离诱惑。（新闻来源请参考：《冲上...  BV1u94y1B7Qh  1048581
# 1  根据相关媒体报道的现有信息，我们聊一聊修桥收费与寻衅滋事。希望大家和我一起关注后续的报道和最...  BV1KX4y1e7cP  5867642
# 2  在这个信息化的社会，个人信息的泄露无处不在。冒名顶替者固然令人愤恨，但是办案机关再发现错误之...  BV1ms4y1F7Fz  1231138
# 3                  其实骗子没有你想得那么傻，自认为聪明的我们肯定比我们想象中更愚蠢。  BV1zh4y1g7PS  1755260
# 4                                  冰冷的法律问题背后是沉甸甸的故事。  BV1wh4y1R7CF  1065630
#
#       评论     弹幕     点赞     投币    收藏    转发     时长                 上传时间
# 0   5240   4087   7.5万   9662  4671  6216  07:34  2023-07-15 12:00:00
# ...

# %%
df['Month'] = pd.to_datetime(df['上传时间']).dt.strftime('%Y-%m')
monthly_avg_plays = df.groupby('Month')['播放量'].mean().reset_index()
monthly_avg_plays_2020 = monthly_avg_plays[:10]
monthly_avg_plays_2021 = monthly_avg_plays[10:22]
monthly_avg_plays_2022 = monthly_avg_plays[22:34]
monthly_avg_plays_2023 = monthly_avg_plays[34:]
monthly_avg_plays_2023
# Out:
#       Month           播放量
# 34  2023-01  1.421060e+06
# 35  2023-02  1.171829e+06
# 36  2023-03  1.140472e+06
# 37  2023-04  1.568756e+06
# 38  2023-05  1.974046e+06
# 39  2023-06  1.410445e+06
# 40  2023-07  2.715787e+06

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar

c = (
    Bar()
    .add_xaxis(monthly_avg_plays_2020['Month'].tolist())
    .add_yaxis("", monthly_avg_plays_2020['播放量'].tolist())
    .set_global_opts(
        xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-15)),
        title_opts=opts.TitleOpts(title="B站罗翔视频可视化", subtitle="2020年每月视频播放平均数"),
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="1a133b8be39b450ba639e89231b377e6" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_1a133b8be39b450ba639e89231b377e6 = echarts.init(
#                     document.getElementById('1a133b8be39b450ba639e89231b377e6'), 'white', {renderer: 'canvas'});
#                 var option_1a133b8be39b450ba639e89231b377e6 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
c = (
    Bar()
    .add_xaxis(monthly_avg_plays_2021['Month'].tolist())
    .add_yaxis("", monthly_avg_plays_2021['播放量'].tolist())
    .set_global_opts(
        xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-15)),
        title_opts=opts.TitleOpts(title="B站罗翔视频可视化", subtitle="2021年每月视频播放平均数"),
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="b0e58a3640514431a53155505ad82419" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_b0e58a3640514431a53155505ad82419 = echarts.init(
#                     document.getElementById('b0e58a3640514431a53155505ad82419'), 'white', {renderer: 'canvas'});
#                 var option_b0e58a3640514431a53155505ad82419 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
c = (
    Bar()
    .add_xaxis(monthly_avg_plays_2022['Month'].tolist())
    .add_yaxis("", monthly_avg_plays_2022['播放量'].tolist())
    .set_global_opts(
        xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-15)),
        title_opts=opts.TitleOpts(title="B站罗翔视频可视化", subtitle="2022年每月视频播放平均数"),
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="1f0a399d8bd4408c9a7d2a5c2e5417ca" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_1f0a399d8bd4408c9a7d2a5c2e5417ca = echarts.init(
#                     document.getElementById('1f0a399d8bd4408c9a7d2a5c2e5417ca'), 'white', {renderer: 'canvas'});
#                 var option_1f0a399d8bd4408c9a7d2a5c2e5417ca = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
c = (
    Bar()
    .add_xaxis(monthly_avg_plays_2023['Month'].tolist())
    .add_yaxis("", monthly_avg_plays_2023['播放量'].tolist())
    .set_global_opts(
        xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-15)),
        title_opts=opts.TitleOpts(title="B站罗翔视频可视化", subtitle="2023年每月视频播放平均数"),
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="d5e84a512cab47868986239b9a4492f1" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_d5e84a512cab47868986239b9a4492f1 = echarts.init(
#                     document.getElementById('d5e84a512cab47868986239b9a4492f1'), 'white', {renderer: 'canvas'});
#                 var option_d5e84a512cab47868986239b9a4492f1 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
df['月份'] = pd.to_datetime(df['上传时间']).dt.strftime('%Y-%m')
monthly_total_plays_all = df.groupby('月份')['播放量'].sum().reset_index()
monthly_avg_plays_2020 = monthly_total_plays_all[:10]
monthly_avg_plays_2021 = monthly_total_plays_all[10:22]
monthly_avg_plays_2022 = monthly_total_plays_all[22:34]
monthly_avg_plays_2023 = monthly_total_plays_all[34:]
monthly_avg_plays_2023
# Out:
#          月份       播放量
# 34  2023-01   7105299
# 35  2023-02   7030974
# 36  2023-03   7983302
# 37  2023-04   9412534
# 38  2023-05  11844275
# 39  2023-06   2820890
# 40  2023-07   8147361

# %%
c = (
    Bar()
    .add_xaxis(monthly_avg_plays_2020['月份'].tolist())
    .add_yaxis("", monthly_avg_plays_2020['播放量'].tolist())
    .set_global_opts(
        xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-15)),
        title_opts=opts.TitleOpts(title="B站罗翔视频可视化", subtitle="2020年每月视频总播放平均数"),
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="34916dacc3d043ebb2f97777c66eda54" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_34916dacc3d043ebb2f97777c66eda54 = echarts.init(
#                     document.getElementById('34916dacc3d043ebb2f97777c66eda54'), 'white', {renderer: 'canvas'});
#                 var option_34916dacc3d043ebb2f97777c66eda54 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
c = (
    Bar()
    .add_xaxis(monthly_avg_plays_2021['月份'].tolist())
    .add_yaxis("", monthly_avg_plays_2021['播放量'].tolist())
    .set_global_opts(
        xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-15)),
        title_opts=opts.TitleOpts(title="B站罗翔视频可视化", subtitle="2021年每月视频总播放平均数"),
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="f19c2210af67431bb46a6f8373425e0a" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_f19c2210af67431bb46a6f8373425e0a = echarts.init(
#                     document.getElementById('f19c2210af67431bb46a6f8373425e0a'), 'white', {renderer: 'canvas'});
#                 var option_f19c2210af67431bb46a6f8373425e0a = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
c = (
    Bar()
    .add_xaxis(monthly_avg_plays_2022['月份'].tolist())
    .add_yaxis("", monthly_avg_plays_2022['播放量'].tolist())
    .set_global_opts(
        xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-15)),
        title_opts=opts.TitleOpts(title="B站罗翔视频可视化", subtitle="2022年每月视频总播放平均数"),
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="7c43ab61013244bab4d4b63d510977d0" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_7c43ab61013244bab4d4b63d510977d0 = echarts.init(
#                     document.getElementById('7c43ab61013244bab4d4b63d510977d0'), 'white', {renderer: 'canvas'});
#                 var option_7c43ab61013244bab4d4b63d510977d0 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
c = (
    Bar()
    .add_xaxis(monthly_avg_plays_2023['月份'].tolist())
    .add_yaxis("", monthly_avg_plays_2023['播放量'].tolist())
    .set_global_opts(
        xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-15)),
        title_opts=opts.TitleOpts(title="B站罗翔视频可视化", subtitle="2023年每月视频总播放平均数"),
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="e24446a2e04843e8bcaaff09512f1acb" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_e24446a2e04843e8bcaaff09512f1acb = echarts.init(
#                     document.getElementById('e24446a2e04843e8bcaaff09512f1acb'), 'white', {renderer: 'canvas'});
#                 var option_e24446a2e04843e8bcaaff09512f1acb = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
df['Year'] = pd.to_datetime(df['上传时间']).dt.strftime('%Y')
yearly_avg_plays = df.groupby('Year')['播放量'].mean().reset_index()
c = (
    Bar()
    .add_xaxis(yearly_avg_plays['Year'].tolist())
    .add_yaxis("", yearly_avg_plays['播放量'].tolist())
    .set_global_opts(
        xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-15)),
        title_opts=opts.TitleOpts(title="B站罗翔视频可视化", subtitle="每年视频播放量平均数"),
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="d27fe28a02384fd39e9bbaddfb3effb3" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_d27fe28a02384fd39e9bbaddfb3effb3 = echarts.init(
#                     document.getElementById('d27fe28a02384fd39e9bbaddfb3effb3'), 'white', {renderer: 'canvas'});
#                 var option_d27fe28a02384fd39e9bbaddfb3effb3 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
df['年份'] = pd.to_datetime(df['上传时间']).dt.strftime('%Y')
yearly_total_plays_all = df.groupby('年份')['播放量'].sum().reset_index()
yearly_total_plays_all
# Out:
#      年份        播放量
# 0  2020  399535615
# 1  2021  230613436
# 2  2022  147812874
# 3  2023   54344635

# %%
c = (
    Bar()
    .add_xaxis(yearly_total_plays_all['年份'].tolist())
    .add_yaxis("", yearly_total_plays_all['播放量'].tolist())
    .set_global_opts(
        xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-15)),
        title_opts=opts.TitleOpts(title="B站罗翔视频可视化", subtitle="每年视频总播放量"),
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="c0e92ae79c714da3af8d39e2da63e3e1" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_c0e92ae79c714da3af8d39e2da63e3e1 = echarts.init(
#                     document.getElementById('c0e92ae79c714da3af8d39e2da63e3e1'), 'white', {renderer: 'canvas'});
#                 var option_c0e92ae79c714da3af8d39e2da63e3e1 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
df.head()
# Out:
#                                                   标题  \
# 0                               【罗翔】张三打牌只算娱乐？怎样判定赌博？
# 1                        【罗翔】村民修桥收费被判处寻衅滋事，这件事应该如何看？
# 2  【罗翔】张三莫名坐牢，有了犯罪记录该怎么办？附《流程图》、《出具无犯罪记录证明的申请》与《行...
# 3                       【罗翔】欠款？上门击毙！我是孙中山，打钱！骗子这么傻么？
# 4           【罗翔】“铁马冰河”买药治疗癫痫女儿，以治病为名购买麻醉药品构成什么走私毒品罪吗
#
#                                                   描述           Bv号      播放量  \
# 0  对于赌博，有行政处罚和刑事惩罚两种。面对诱惑，我们只能选择远离诱惑。（新闻来源请参考：《冲上...  BV1u94y1B7Qh  1048581
# 1  根据相关媒体报道的现有信息，我们聊一聊修桥收费与寻衅滋事。希望大家和我一起关注后续的报道和最...  BV1KX4y1e7cP  5867642
# 2  在这个信息化的社会，个人信息的泄露无处不在。冒名顶替者固然令人愤恨，但是办案机关再发现错误之...  BV1ms4y1F7Fz  1231138
# 3                  其实骗子没有你想得那么傻，自认为聪明的我们肯定比我们想象中更愚蠢。  BV1zh4y1g7PS  1755260
# 4                                  冰冷的法律问题背后是沉甸甸的故事。  BV1wh4y1R7CF  1065630
#
#       评论     弹幕     点赞     投币    收藏    转发     时长                 上传时间  \
# 0   5240   4087   7.5万   9662  4671  6216  07:34  2023-07-15 12:00:00
# ...

# %%
top10 = df[['标题', '弹幕']].sort_values('弹幕', ascending=False)[:10]
names = list(top10['标题'])
counts = list(top10['弹幕'])
c = (
    Bar()
    .add_xaxis(names)
    .add_yaxis("", counts)
    .reversal_axis()
    .set_series_opts(label_opts=opts.LabelOpts(position="right"))
    .set_global_opts(title_opts=opts.TitleOpts(title="弹幕量Top10"))
#     .render("bar_reversal_axis.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="ce68a2bc4d45435c8878ae1d208098a8" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_ce68a2bc4d45435c8878ae1d208098a8 = echarts.init(
#                     document.getElementById('ce68a2bc4d45435c8878ae1d208098a8'), 'white', {renderer: 'canvas'});
#                 var option_ce68a2bc4d45435c8878ae1d208098a8 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
top10 = df[['标题', '评论']].sort_values('评论', ascending=False)[:10]
names = list(top10['标题'])
counts = list(top10['评论'])
c = (
    Bar()
    .add_xaxis(names)
    .add_yaxis("", counts)
    .reversal_axis()
    .set_series_opts(label_opts=opts.LabelOpts(position="right"))
    .set_global_opts(title_opts=opts.TitleOpts(title="评论量Top10"))
#     .render("bar_reversal_axis.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="5e873fc3f1f24b5f8093d2e377c9797f" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_5e873fc3f1f24b5f8093d2e377c9797f = echarts.init(
#                     document.getElementById('5e873fc3f1f24b5f8093d2e377c9797f'), 'white', {renderer: 'canvas'});
#                 var option_5e873fc3f1f24b5f8093d2e377c9797f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...
